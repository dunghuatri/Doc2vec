# %%
import pandas as pd
import glob
from gensim.models.doc2vec import TaggedDocument
from gensim import utils
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
source = "data/a2"
allFiles = glob.glob(source + "/*.csv")
sentences = []
n = 0
for file_ in allFiles:
    df = pd.read_csv(file_)
    for line in df['content']:
        print(n)
        sentences.append(TaggedDocument(utils.to_unicode(line).split(), ['_%s' %n]))
        n = n+1
    
#     content = df['content']
#     for row in content:
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-82169882449f> in <module>()
#       7     for line in df['content']:
#       8         print(n)
# ----> 9         sentences.append(TaggedDocument(utils.to_unicode(line).split(), ['_%s' %n]))
#      10         n = n+1
#      11
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in any2unicode(text, encoding, errors)
#     357     if isinstance(text, unicode):
#     358         return text
# --> 359     return unicode(text, encoding, errors=errors)
#     360
#     361
#
# TypeError: decoding to str: need a bytes-like object, float found

# %%
df = pd.read_csv('data/a2/data-news.csv')
df
# Out:
#            id                                              title  \
# 0     3237408  đi tìm gam màu hot mỹ_nhân việt yêu_thích ngày...
# 1    72822816                            vtv thiên_thần biết yêu
# 2   111017033                       sinh_tố đu_đủ làm dễ ngon_bổ
# 3   113808836            bi hài sĩ tử kiêng gặp bà chửa ngày thi
# 4     3237380  angela phương_trinh mỹ_nhân khoe vòng táo_bạo ...
# 5    57202135  mỹ_nhân việt táo_bạo khoe chân với jumpsuit si...
# 6    57202148        mách bạn gái cách mặc đẹp với chân váy ngắn
# 7    57238803                 hoa_hậu bí_ẩn việt_nam lộ diện năm
# 8    57278208                        khổ_sở không_thể đáp_ứng vợ
# 9     3307488  cám_cảnh người cựu_binh bỏng nặngthập_tử_nhất_...
# 10    9931592                               đoán vận ngày tháng
# 11    3299751   nhặt_sạn phim hoa_thiên_cốt nhặt_sạn phim hoa...
# 12   56925174                     audi thế_hệ nâng_cấp công_nghệ
# ...

# %%
import psutil
print(psutil.virtual_memory())
# Out:
# svmem(total=8451575808, available=2760441856, percent=67.3, used=5691133952, free=2760441856)

# %%
source = "data/a2"
allFiles = glob.glob(source + "/*.csv")
sentences = []
n = 0
for file_ in allFiles:
    df = pd.read_csv(file_)
    content = df['content']
    content = content.dropna()
    for line in content:
        sentences.append(TaggedDocument(utils.to_unicode(line).split(), ['_%s' %n]))
        n = n+1
    
#     content = df['content']
#     for row in content:

# %%
import psutil
print(psutil.virtual_memory())
# Out:
# svmem(total=8451575808, available=2759155712, percent=67.4, used=5692420096, free=2759155712)

# %%
import sys
sys.getsizeof(sentences)
# Out:
# 192
